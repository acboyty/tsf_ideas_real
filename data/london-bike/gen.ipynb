# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/home/v-tyan/tsf_ideas_real/data/london-bike/london_merged.csv')

# %%
df.head(50)
# Out:
#               timestamp   cnt    t1   t2    hum  wind_speed  weather_code  \
# 0   2015-01-04 00:00:00   182   3.0  2.0   93.0         6.0           3.0
# 1   2015-01-04 01:00:00   138   3.0  2.5   93.0         5.0           1.0
# 2   2015-01-04 02:00:00   134   2.5  2.5   96.5         0.0           1.0
# 3   2015-01-04 03:00:00    72   2.0  2.0  100.0         0.0           1.0
# 4   2015-01-04 04:00:00    47   2.0  0.0   93.0         6.5           1.0
# 5   2015-01-04 05:00:00    46   2.0  2.0   93.0         4.0           1.0
# 6   2015-01-04 06:00:00    51   1.0 -1.0  100.0         7.0           4.0
# 7   2015-01-04 07:00:00    75   1.0 -1.0  100.0         7.0           4.0
# 8   2015-01-04 08:00:00   131   1.5 -1.0   96.5         8.0           4.0
# 9   2015-01-04 09:00:00   301   2.0 -0.5  100.0         9.0           3.0
# 10  2015-01-04 10:00:00   528   3.0 -0.5   93.0        12.0           3.0
# 11  2015-01-04 11:00:00   727   2.0 -1.5  100.0        12.0           3.0
# ...

# %%
data = df[['cnt', 'is_holiday']].values.astype('float')

# %%
data[:-1, 1] = data[1:, 1]

# %%
data[:, 0] = (data[:, 0] - np.min(data[:, 0])) / (np.max(data[:, 0]) - np.min(data[:, 0]))

# %%
np.max(data)
# Out:
# 1.0

# %%
np.save('data', data)

# %%
plt.figure(figsize=(20, 5))
plt.scatter(np.arange(len(df[:400])), df.cnt[:400])

# %%
data = np.load('data.npy')

# %%
data.shape
# Out:
# (17414, 2)

# %%
plt.figure(figsize=(20, 5))
plt.plot(range(500), data[2000:2500, 0])
plt.twinx()
plt.scatter(range(500), data[2000:2500, 1], c='r')

# %%
plt.figure(figsize=(20, 5))
plt.plot(range(500), data[3000:3500, 0])
plt.twinx()
plt.scatter(range(500), data[3000:3500, 1], c='r')
